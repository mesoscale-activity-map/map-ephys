# %%
import datajoint as dj

# %%
import mock
# Out:
# Connecting daveliu@mesoscale-activity.datajoint.io:3306

# %%
import ephys
import lab
import experiment
import ccf

# %%
dj.ERD(experiment)

# %%
experiment.Tracking()
# Out:
# *animal    *session    *trial    *tracking_devi tracking_data_
# +--------+ +---------+ +-------+ +------------+ +------------+
#
#  (0 tuples)

# %%
experiment.TrackingDevice()
# Out:
# *tracking_devi sampling_rate
# +------------+ +------------+
#
#  (0 tuples)
