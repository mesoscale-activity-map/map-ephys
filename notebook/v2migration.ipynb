# %%
import datajoint as dj
from pipeline import lab
lab_v1 = dj.create_virtual_module('lab_v1', 'map_v1_lab')
# Out:
# Connecting daveliu@mesoscale-activity.datajoint.io:3306

# %%
behavior_ingest.RigDataPath.delete()
# Out:
# About to delete:
# `map_v2_ingest_behavior`.`#rig_data_path`: 4 items
# Committed.

# %%
from pipeline.ingest import behavior as behavior_ingest

# %%
from pipeline.ingest import ephys as ephys_ingest

# %%
from pipeline import experiment, ephys, tracking, publication

# %%
lab.WaterRestriction()
# Out:
# *subject_id    water_restrict cage_number    wr_start_date  wr_start_weigh
# +------------+ +------------+ +------------+ +------------+ +------------+
# 412330         tw34           154522         2018-03-18     21.000
# 412753         dl36           154570         2017-03-30     21.000
# 413950         dl40           155585         2018-04-18     21.000
# 418279         dl41           155593         2018-04-19     21.000
# 428047         dl51           158986         2018-07-11     21.000
# 428048         dl52           158987         2018-07-12     21.000
# 432570         dl57           161126         2018-09-10     21.000
#    ...
#  (Total: 28)

# %%
experiment.Session.delete()
# Out:
# About to delete:
# `map_v2_ingest_behavior`.`_behavior_ingest__behavior_file`: 19 items
# `map_v2_ingest_behavior`.`_behavior_ingest`: 16 items
# `map_v2_experiment`.`_photostim_event`: 1379 items
# `map_v2_experiment`.`photostim__photostim_location`: 3 items
# `map_v2_experiment`.`photostim`: 2 items
# `map_v2_experiment`.`_action_event`: 83821 items
# `map_v2_experiment`.`_trial_event`: 61145 items
# `map_v2_experiment`.`_behavior_trial`: 10794 items
# `map_v2_experiment`.`_photostim_trial`: 1379 items
# `map_v2_experiment`.`_trial_note`: 32382 items
# `map_v2_experiment`.`_session_trial`: 10794 items
# `map_v2_experiment`.`session`: 16 items
# Committed.

# %%
lab_v1.Subject()
# Out:
# *subject_id    username     cage_number    date_of_birth  sex     animal_source
# +------------+ +----------+ +------------+ +------------+ +-----+ +------------+
# 412330         daveliu      154522         2017-12-05     M       Jackson labs
# 412753         daveliu      154570         2017-12-07     M       Jackson labs
# 413950         daveliu      155585         2017-12-21     M       Jackson labs
# 418279         daveliu      155593         2018-02-02     M       Jackson labs
# 428047         daveliu      158986         2018-05-16     M       Jackson labs
# 428048         daveliu      158987         2018-05-16     M       Jackson labs
# 432570         daveliu      161126         2018-06-28     M       Jackson labs
#    ...
#  (Total: 28)

# %%
lab.WaterRestriction.insert(lab_v1.WaterRestriction)

# %%
lab.Subject.insert(lab_v1.Subject)

# %%
lab.ProbeType.create_neuropixels_probe()

# %%
lab.ProbeType.Electrode()
# Out:
# *probe_type    *electrode    shank     shank_col     shank_row     x_coord     y_coord     z_coord
# +------------+ +-----------+ +-------+ +-----------+ +-----------+ +---------+ +---------+ +---------+
# neuropixels 1. 1             0         0             0             16.0        0.0         0.0
# neuropixels 1. 2             0         1             0             48.0        0.0         0.0
# neuropixels 1. 3             0         0             1             0.0         20.0        0.0
# neuropixels 1. 4             0         1             1             32.0        20.0        0.0
# neuropixels 1. 5             0         0             2             16.0        40.0        0.0
# neuropixels 1. 6             0         1             2             48.0        40.0        0.0
# neuropixels 1. 7             0         0             3             0.0         60.0        0.0
#    ...
#  (Total: 1920)

# %%
from pipeline import shell

# %%
shell.ingest_ephys()
# Out:
#   0%|                                                  | 0/567 [00:00<?, ?it/s]Error - no ap.meta files in [0-9]/{}. Skipping.
# Error - no ap.meta files in [0-9]/{}. Skipping.
#   0%|▏                                         | 2/567 [00:00<00:52, 10.69it/s]Error - no ap.meta files in [0-9]/{}. Skipping.
#   1%|▏                                         | 3/567 [00:00<00:53, 10.45it/s]Error - no ap.meta files in [0-9]/{}. Skipping.
#   1%|▎                                         | 4/567 [00:00<00:54, 10.28it/s]Error - no ap.meta files in [0-9]/{}. Skipping.
# Error - no ap.meta files in [0-9]/{}. Skipping.
#   1%|▍                                         | 6/567 [00:00<00:54, 10.20it/s]Error - no ap.meta files in [0-9]/{}. Skipping.
#   1%|▌                                         | 7/567 [00:00<00:55, 10.16it/s]Error - no ap.meta files in [0-9]/{}. Skipping.
#   1%|▌                                         | 8/567 [00:00<00:55, 10.14it/s]Error - no ap.meta files in [0-9]/{}. Skipping.
#   2%|▋                                         | 9/567 [00:00<00:55, 10.11it/s]Error - no ap.meta files in [0-9]/{}. Skipping.
#