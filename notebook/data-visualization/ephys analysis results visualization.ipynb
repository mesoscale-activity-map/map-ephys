# %%
# %cd ..\..
import datajoint as dj
dj.conn().connect()
# Out:
# D:\Han_Sync\Svoboda\Scripts\map-ephys
# Connecting hanhou@datajoint.mesoscale-activity-map.org:3306

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from scipy import signal

from pipeline import lab, experiment, ephys, histology, psth
from pipeline.plot import unit_characteristic_plot

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Visualization of ephys analysis results
#
# This notebook demonstrates data visualization with the MAP pipeline, specifically focus on the queries and visualizations of the ephys analysis results, using the provided MAP built-in visualization functions
#
# This notebook presents and demonstrates 9 built-in functions - part of the ***unit_characteristic_plot*** module:
# + plot_clustering_quality(***probe insertion***)
# + plot_unit_characteristic(***probe insertion***)
#
# + plot_unit_selectivity(***probe insertion***)
# + plot_unit_bilateral_photostim_effect(***probe insertion***)
#
# + plot_stacked_contra_ipsi_psth(***units***)
# + plot_avg_contra_ipsi_psth(***units***)
# + plot_psth_bilateral_photostim_effect(***units***)
# + plot_coding_direction(***units***)
# + plot_paired_coding_direction(***units***)
#
# See below for the ERD(s) of the relevant portions of the MAP pipeline for this notebook

# %%
unit_erd = ((dj.ERD(ephys.ProbeInsertion.InsertionLocation) - 1)
            + (dj.ERD(psth.UnitSelectivity))
            + (dj.ERD(psth.UnitPsth))
            + (dj.ERD(ephys.ProbeInsertion.RecordableBrainRegion) - 1)
            + (dj.ERD(ephys.Unit) - 1))

# %%
unit_erd

# %% [markdown]
# ## Part 1: Unit quality from a clustering analysis

# %% [markdown]
# ### The MAP pipeline provides 2 built-in functions for visualizing the clustering quality
# + unit_characteristic_plot.plot_clustering_quality(***probe insertion***)
# + unit_characteristic_plot.plot_unit_characteristic(***probe insertion***)
#
# Note: since clustering is performed per ***probe insertion***, these functions take ***probe insertion*** as input. This input ***probe insertion*** can take the form of a queried expression of the ***ephys.ProbeInsertion*** table (see examples below).

# %% [markdown]
# #### Start by selecting a ***probe insertion***

# %% [markdown]
# ##### Here, we can start by viewing all of the probe insertion with ***PSTH*** and ***Selectivity*** calculated.

# %%
ephys.ProbeInsertion & psth.UnitPsth & psth.UnitSelectivity
# Out:
# *subject_id    *session    *insertion_number    probe     probe_type     electrode_config_name
# +------------+ +---------+ +------------------+ +-------+ +------------+ +-----------------------+
#
#  (Total: 0)

# %% [markdown]
# ##### Then, we can pick one by restricting to the ***subject***, ***session*** and ***insertion_number*** of interest

# %%
probe_insertion = (ephys.ProbeInsertion)

# %%
probe_insertion()
# Out:
# *subject_id    *session    *insertion_number    probe           probe_type               electrode_config_name
# +------------+ +---------+ +------------------+ +-------------+ +----------------------+ +---------------------------------------+
# 473361         42          1                    17131309211     neuropixels 1.0 - 3B     1-384
# 473361         46          1                    18005108622     neuropixels 1.0 - 3B     1-384
# 473361         46          2                    18005123491     neuropixels 1.0 - 3B     1-384
# 473361         47          1                    18005123491     neuropixels 1.0 - 3B     1-384
# 473361         47          2                    19122516811     neuropixels 2.0 - MS     1-96; 1281-1376; 2561-2656; 3841-3936
# 473361         48          1                    18005123491     neuropixels 1.0 - 3B     1-384
# 473361         48          2                    19122516691     neuropixels 2.0 - MS     1-96; 1281-1376; 2561-2656; 3841-3936
# 473361         50          1                    18005123491     neuropixels 1.0 - 3B     1-384
# 473361         50          2                    19122516811     neuropixels 2.0 - MS     1-96; 1281-1376; 2561-2656; 3841-3936
# 473361         57          1                    19122516811     neuropixels 2.0 - MS     1-96; 1281-1376; 2561-2656; 3841-3936
# 473361         57          2                    18005123491     neuropixels 1.0 - 3B     1-384
# 473361         58          1                    18005123491     neuropixels 1.0 - 3B     1-384
# 473361         58          2                    19122516811     neuropixels 2.0 - MS     1-96; 1281-1376; 2561-2656; 3841-3936
# 473361         59          1                    19122516811     neuropixels 2.0 - MS     1-96; 1281-1376; 2561-2656; 3841-3936
# 473361         59          2                    18005123491     neuropixels 1.0 - 3B     1-384
# 473361         60          1                    18005123491     neuropixels 1.0 - 3B     1-384
# 473361         60          2                    18005108622     neuropixels 1.0 - 3B     1-384
# 473361         61          1                    18005123491     neuropixels 1.0 - 3B     1-384
#  (Total: 18)

# %% [markdown]
# ##### Inspecting the *selectivity* of all the units in the selected probe insertion

# %%
psth.UnitSelectivity & probe_insertion
# Out:
# *subject_id    *session    *insertion_number    *clustering_method    *unit    unit_selectivity
# +------------+ +---------+ +------------------+ +-------------------+ +------+ +------------------+
#
#  (Total: 0)

# %% [markdown]
# #### Plot Clustering Quality

# %%
fig1a = unit_characteristic_plot.plot_clustering_quality(probe_insertion)

# %% [markdown]
# #### Plot unit characteristic - overlay on probe

# %%
fig1b = unit_characteristic_plot.plot_unit_characteristic(probe_insertion)

# %% [markdown]
# ## Part 2: Other unit characteristic - as a function of position on probe

# %% [markdown]
# + unit_characteristic_plot.plot_unit_selectivity(***probe insertion***)
# + unit_characteristic_plot.plot_unit_bilateral_photostim_effect(***probe insertion***)

# %% [markdown]
# #### Plot unit selectivity - overlay on probe

# %%
fig2a = unit_characteristic_plot.plot_unit_selectivity(probe_insertion)

# %% [markdown]
# #### Plot effect of bilateral perturbation - overlay on probe

# %%
fig2b = unit_characteristic_plot.plot_unit_bilateral_photostim_effect(probe_insertion)

# %% [markdown]
# ## Part 3: Unit PSTH and Unit Selectivity

# %% [markdown]
# ### The MAP pipeline provides 5 built-in functions for visualizing unit PSTH
# + unit_characteristic_plot.plot_stacked_contra_ipsi_psth(***units***)
# + unit_characteristic_plot.plot_avg_contra_ipsi_psth(***units***)
# + unit_characteristic_plot.plot_psth_bilateral_photostim_effect(***units***)
# + unit_characteristic_plot.plot_coding_direction(***units***)
# + unit_characteristic_plot.plot_paired_coding_direction(***units***)
#
# Note: These functions visualize the PSTH of a group of units in various ways, thus the input to these functions is a group of units, this can be specified as a queried expression of the ***ephys.Unit*** table (see examples below).

# %% [markdown]
# #### Let's pick the units from session 64 on animal 412330, where the probe was inserted in right ALM

# %%
units = ephys.Unit & {'subject_id': 412330, 'session': 64} \
& (ephys.ProbeInsertion.RecordableBrainRegion & {'brain_area': 'alm', 'hemisphere': 'right'})

# %% [markdown]
# #### Let's exclude the units of type "all"

# %%
units = units & 'unit_quality != "all"'

# %%
units
# Out:
# *subject_id    *session    *insertion_num *clustering_me *unit    unit_uid     unit_quality   probe_type     electrode_conf electrode_grou electrode     unit_posx      unit_posy      spike_time unit_amp      unit_snr      waveform
# +------------+ +---------+ +------------+ +------------+ +------+ +----------+ +------------+ +------------+ +------------+ +------------+ +-----------+ +------------+ +------------+ +--------+ +-----------+ +-----------+ +--------+
# 412330         64          1              jrclust_v3     7        7            good           neuropixels 1. 1-384          0              3             7.404426574707 23.03435897827 =BLOB=     427.98932     13.06085      =BLOB=
# 412330         64          1              jrclust_v3     8        8            good           neuropixels 1. 1-384          0              3             3.042593002319 19.83121109008 =BLOB=     290.44583     7.659547      =BLOB=
# 412330         64          1              jrclust_v3     12       12           good           neuropixels 1. 1-384          0              4             32.34442520141 16.04660415649 =BLOB=     225.7262      11.071866     =BLOB=
# 412330         64          1              jrclust_v3     18       18           good           neuropixels 1. 1-384          0              11            6.865122795104 96.26170349121 =BLOB=     296.88046     12.259954     =BLOB=
# 412330         64          1              jrclust_v3     33       33           multi          neuropixels 1. 1-384          0              15            1.165773510932 140.0749206542 =BLOB=     291.5367      11.471023     =BLOB=
# 412330         64          1              jrclust_v3     34       34           good           neuropixels 1. 1-384          0              15            2.568069934844 142.5044860839 =BLOB=     231.31876     8.671488      =BLOB=
# 412330         64          1              jrclust_v3     35       35           good           neuropixels 1. 1-384          0              21            15.26202869415 201.5188598632 =BLOB=     241.5961      7.549255      =BLOB=
# 412330         64          1              jrclust_v3     38       38           good           neuropixels 1. 1-384          0              18            46.01060485839 161.5317077636 =BLOB=     330.37268     11.911634     =BLOB=
# 412330         64          1              jrclust_v3     49       49           multi          neuropixels 1. 1-384          0              23            3.594064474105 220.0469970703 =BLOB=     329.72577     10.56204      =BLOB=
# 412330         64          1              jrclust_v3     53       53           good           neuropixels 1. 1-384          0              25            16.01881027221 239.9638366699 =BLOB=     229.43436     8.782874      =BLOB=
# 412330         64          1              jrclust_v3     57       57           good           neuropixels 1. 1-384          0              27            4.520862102508 264.2856750488 =BLOB=     546.9844      21.392849     =BLOB=
# 412330         64          1              jrclust_v3     58       58           good           neuropixels 1. 1-384          0              27            0.445345163345 259.9233398437 =BLOB=     305.38354     12.988269     =BLOB=
#    ...
#  (Total: 47)

# %% [markdown]
# #### Plot unit PSTHs categorized by selectivity

# %%
fig3a = unit_characteristic_plot.plot_stacked_contra_ipsi_psth(units)

# %% [markdown]
# ####  Plot average PSTH categorized by selectivy

# %%
fig3b = unit_characteristic_plot.plot_avg_contra_ipsi_psth(units)

# %% [markdown]
# #### For visualizing the effect of bilateral perturbation, let's compare the units from the ALM vs. Thalamus based on the probe insertion location - from all sessions of animal 412330

# %%
units = ephys.Unit * ephys.ProbeInsertion.RecordableBrainRegion & 'subject_id = 412753'

# %%
units = units & 'unit_quality = "good"'

# %%
units
# Out:
# *subject_id    *session    *insertion_num *clustering_me *unit    *brain_area    *hemisphere    unit_uid     unit_quality   probe_type     electrode_conf electrode_grou electrode     unit_posx      unit_posy      spike_time unit_amp       unit_snr      waveform
# +------------+ +---------+ +------------+ +------------+ +------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +-----------+ +------------+ +------------+ +--------+ +------------+ +-----------+ +--------+
# 412753         89          1              jrclust_v3     1        ALM            right          1            good           neuropixels 1. 1-384          0              2             44.52645874023 1.717340230941 =BLOB=     166.25258      9.730891      =BLOB=
# 412753         89          1              jrclust_v3     2        ALM            right          2            good           neuropixels 1. 1-384          0              2             37.63747787475 4.586958885192 =BLOB=     98.09725       6.4640074     =BLOB=
# 412753         89          1              jrclust_v3     3        ALM            right          3            good           neuropixels 1. 1-384          0              6             46.72496795654 39.45938873291 =BLOB=     116.633896     7.1068344     =BLOB=
# 412753         89          1              jrclust_v3     4        ALM            right          4            good           neuropixels 1. 1-384          0              6             44.58914184570 35.94406127929 =BLOB=     245.79802      15.696075     =BLOB=
# 412753         89          1              jrclust_v3     5        ALM            right          5            good           neuropixels 1. 1-384          0              7             5.701788902282 57.02951049804 =BLOB=     94.57545       6.8286357     =BLOB=
# 412753         89          1              jrclust_v3     51       ALM            right          51           good           neuropixels 1. 1-384          0              17            11.98251914978 159.1456604003 =BLOB=     119.50731      6.17433       =BLOB=
# 412753         89          1              jrclust_v3     52       ALM            right          52           good           neuropixels 1. 1-384          0              17            12.03704166412 155.4549255371 =BLOB=     121.01767      6.4501233     =BLOB=
# 412753         89          1              jrclust_v3     53       ALM            right          53           good           neuropixels 1. 1-384          0              18            34.83239364624 158.1232604980 =BLOB=     67.44633       6.452573      =BLOB=
# 412753         89          1              jrclust_v3     54       ALM            right          54           good           neuropixels 1. 1-384          0              19            10.52071762084 176.7315979003 =BLOB=     85.81075       6.7696877     =BLOB=
# 412753         89          1              jrclust_v3     57       ALM            right          57           good           neuropixels 1. 1-384          0              20            29.57561111450 177.4954528808 =BLOB=     90.201935      5.858861      =BLOB=
# 412753         89          1              jrclust_v3     64       ALM            right          64           good           neuropixels 1. 1-384          0              22            45.07836151123 198.9994506835 =BLOB=     103.92063      6.753752      =BLOB=
# 412753         89          1              jrclust_v3     65       ALM            right          65           good           neuropixels 1. 1-384          0              23            1.999283075332 219.9112854003 =BLOB=     87.96963       6.4131894     =BLOB=
#    ...
#  (Total: 331)

# %% [markdown]
# ####  Plot average PSTH - effect of bilateral perturbation
#
# Here, we use the `unit_characteristic_plot.plot_psth_photostim_effect()` function that takes a list of unit_keys or a query of the ephys.Unit table

# %%
fig3c = unit_characteristic_plot.plot_psth_photostim_effect(units & 'brain_area = "alm"')

# %%
fig3d = unit_characteristic_plot.plot_psth_photostim_effect(units & 'brain_area = "thalamus"')

# %% [markdown]
# ## Part 4: Plot trial psth projected on the coding direction vector
# Note: CD vector is calculated for:
# + the specified **units**
# + the specified **time_period**

# %% [markdown]
# From the selected units above, let's exclude the `non-selective` ones and select those from `thalamus` only

# %%
units = units * psth.UnitSelectivity & 'unit_selectivity != "non-selective"'

# %%
units
# Out:
# *subject_id    *session    *insertion_num *clustering_me *unit    *brain_area    *hemisphere    unit_uid     unit_quality   probe_type     electrode_conf electrode_grou electrode     unit_posx      unit_posy      spike_time unit_amp       unit_snr      waveform   unit_selectivi
# +------------+ +---------+ +------------+ +------------+ +------+ +------------+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +-----------+ +------------+ +------------+ +--------+ +------------+ +-----------+ +--------+ +------------+
# 412753         89          1              jrclust_v3     1        ALM            right          1            good           neuropixels 1. 1-384          0              2             44.52645874023 1.717340230941 =BLOB=     166.25258      9.730891      =BLOB=     ipsi-selective
# 412753         89          1              jrclust_v3     2        ALM            right          2            good           neuropixels 1. 1-384          0              2             37.63747787475 4.586958885192 =BLOB=     98.09725       6.4640074     =BLOB=     ipsi-selective
# 412753         89          1              jrclust_v3     3        ALM            right          3            good           neuropixels 1. 1-384          0              6             46.72496795654 39.45938873291 =BLOB=     116.633896     7.1068344     =BLOB=     contra-selecti
# 412753         89          1              jrclust_v3     5        ALM            right          5            good           neuropixels 1. 1-384          0              7             5.701788902282 57.02951049804 =BLOB=     94.57545       6.8286357     =BLOB=     ipsi-selective
# 412753         89          1              jrclust_v3     51       ALM            right          51           good           neuropixels 1. 1-384          0              17            11.98251914978 159.1456604003 =BLOB=     119.50731      6.17433       =BLOB=     contra-selecti
# 412753         89          1              jrclust_v3     52       ALM            right          52           good           neuropixels 1. 1-384          0              17            12.03704166412 155.4549255371 =BLOB=     121.01767      6.4501233     =BLOB=     contra-selecti
# 412753         89          1              jrclust_v3     53       ALM            right          53           good           neuropixels 1. 1-384          0              18            34.83239364624 158.1232604980 =BLOB=     67.44633       6.452573      =BLOB=     ipsi-selective
# 412753         89          1              jrclust_v3     54       ALM            right          54           good           neuropixels 1. 1-384          0              19            10.52071762084 176.7315979003 =BLOB=     85.81075       6.7696877     =BLOB=     contra-selecti
# 412753         89          1              jrclust_v3     57       ALM            right          57           good           neuropixels 1. 1-384          0              20            29.57561111450 177.4954528808 =BLOB=     90.201935      5.858861      =BLOB=     contra-selecti
# 412753         89          1              jrclust_v3     64       ALM            right          64           good           neuropixels 1. 1-384          0              22            45.07836151123 198.9994506835 =BLOB=     103.92063      6.753752      =BLOB=     ipsi-selective
# 412753         89          1              jrclust_v3     65       ALM            right          65           good           neuropixels 1. 1-384          0              23            1.999283075332 219.9112854003 =BLOB=     87.96963       6.4131894     =BLOB=     contra-selecti
# 412753         89          1              jrclust_v3     66       ALM            right          66           good           neuropixels 1. 1-384          0              25            12.78532981872 242.1161651611 =BLOB=     114.23714      7.57603       =BLOB=     contra-selecti
#    ...
#  (Total: 293)

# %%
fig4a = unit_characteristic_plot.plot_coding_direction(units & 'brain_area = "thalamus"',  time_period=(-0.4, 0))

# %% [markdown]
# #### Plot trial-to-trial CD-endpoint correlation between two unit groups

# %%
fig4b = unit_characteristic_plot.plot_paired_coding_direction(units & 'brain_area = "thalamus"',
                                                              units & 'brain_area = "alm"',
                                                              labels=('thalamus', 'alm'), time_period=(-0.4, 0))
