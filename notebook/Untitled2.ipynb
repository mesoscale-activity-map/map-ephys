# %%
import datajoint as dj

# %%
from pipeline import shell
# Out:
# Connecting daveliu@mesoscale-activity.datajoint.io:3306

# %%
shell.ingest_tracking()
# Out:
#   0%|                                                  | 0/569 [00:00<?, ?it/s]tracking path H:\data\MAP\tw34\20180611\tracking n/a - skipping
# tracking path H:\data\MAP\tw34\20180611\tracking n/a - skipping
#   0%|                                          | 1/569 [00:00<01:05,  8.62it/s]tracking path H:\data\MAP\tw34\20180612\tracking n/a - skipping
# tracking path H:\data\MAP\tw34\20180612\tracking n/a - skipping
#   0%|▏                                         | 2/569 [00:00<01:05,  8.66it/s]tracking path H:\data\MAP\tw34\20180608\tracking n/a - skipping
# tracking path H:\data\MAP\tw34\20180608\tracking n/a - skipping
#   1%|▏                                         | 3/569 [00:00<01:02,  9.01it/s]tracking path H:\data\MAP\tw34\20180613\tracking n/a - skipping
# tracking path H:\data\MAP\tw34\20180613\tracking n/a - skipping
#   1%|▎                                         | 4/569 [00:00<01:04,  8.73it/s]tracking path H:\data\MAP\tw34\20180614\tracking n/a - skipping
# ...

# %%
from pipeline.ingest import tracking

# %%
tracking.TrackingIngest.delete()
# Out:
# About to delete:
# `map_v2_ingest_tracking`.`_tracking_ingest`: 569 items
# Committed.
