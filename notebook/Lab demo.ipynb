# %%
import sys
import os

# %%
import datajoint as dj

# %%
sys.path.append('c:\\Users\\liul.HHMI\\Desktop\\map-ephys\\pipeline') # go to parent dir
sys.path.append('c:\\Users\\liul.HHMI\\Desktop\\map-ephys\\scripts')
sys.path.append('c:\\Users\\liul.HHMI\\Desktop\\map-ephys\\development')
sys.path.append('c:\\Users\\liul.HHMI\\Desktop\\map-lab')

# %%
print(sys.path)
# Out:
# ['', 'c:\\users\\liul.hhmi\\appdata\\local\\programs\\python\\python36\\python36.zip', 'c:\\users\\liul.hhmi\\appdata\\local\\programs\\python\\python36\\DLLs', 'c:\\users\\liul.hhmi\\appdata\\local\\programs\\python\\python36\\lib', 'c:\\users\\liul.hhmi\\appdata\\local\\programs\\python\\python36', 'c:\\users\\liul.hhmi\\appdata\\local\\programs\\python\\python36\\lib\\site-packages', 'c:\\users\\liul.hhmi\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\liul.HHMI\\.ipython', 'c:\\Users\\liul.HHMI\\Desktop\\map-ephys\\pipeline', 'c:\\Users\\liul.HHMI\\Desktop\\map-ephys\\scripts', 'c:\\Users\\liul.HHMI\\Desktop\\map-ephys\\development', 'c:\\Users\\liul.HHMI\\Desktop\\map-lab']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\liul.HHMI\\Desktop\\map-ephys\\notebook'

# %%
import mock
# Out:
# Connecting daveliu@mesoscale-activity.datajoint.io:3306

# %%
# Out:
# populating with mock data

# %%
import experiment

# %%
dj.ERD(experiment)

# %%
# Out:
# dropping databases
# error dropping ccf in attempt 0: (1451, 'Cannot delete or update a parent row: a foreign key constraint fails')
# error dropping prototype in attempt 0: 'prototype.database'
# error dropping prototype in attempt 1: 'prototype.database'
# error dropping prototype in attempt 2: 'prototype.database'
